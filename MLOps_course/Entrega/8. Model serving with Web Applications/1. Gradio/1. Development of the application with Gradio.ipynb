# %% [markdown]
# # Desarrollo de la aplicación con Gradio

# %%
# load the dataset from pycaret
from pycaret.datasets import get_data
data = get_data('insurance')
# Out:
#    age     sex     bmi  children smoker     region      charges
# 0   19  female  27.900         0    yes  southwest  16884.92400
# 1   18    male  33.770         1     no  southeast   1725.55230
# 2   28    male  33.000         3     no  southeast   4449.46200
# 3   33    male  22.705         0     no  northwest  21984.47061
# 4   32    male  28.880         0     no  northwest   3866.85520

# %%
# initialize setup
from pycaret.regression  import *
s = setup(data, target = 'charges',
    session_id = 123,
         silent = True)
# Out:
# <style type="text/css">
# #T_4defe_row42_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_4defe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_4defe_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_4defe_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_4defe_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_4defe_row0_col0" class="data row0 col0" >session_id</td>
#       <td id="T_4defe_row0_col1" class="data row0 col1" >123</td>
#     </tr>
#     <tr>
#       <th id="T_4defe_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_4defe_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_4defe_row1_col1" class="data row1 col1" >charges</td>
#     </tr>
#     <tr>
#       <th id="T_4defe_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_4defe_row2_col0" class="data row2 col0" >Original Data</td>
#       <td id="T_4defe_row2_col1" class="data row2 col1" >(1338, 7)</td>
#     </tr>
#     <tr>
#       <th id="T_4defe_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_4defe_row3_col0" class="data row3 col0" >Missing Values</td>
#       <td id="T_4defe_row3_col1" class="data row3 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_4defe_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_4defe_row4_col0" class="data row4 col0" >Numeric Features</td>
#       <td id="T_4defe_row4_col1" class="data row4 col1" >2</td>
#     </tr>
#     <tr>
#       <th id="T_4defe_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_4defe_row5_col0" class="data row5 col0" >Categorical Features</td>
#       <td id="T_4defe_row5_col1" class="data row5 col1" >4</td>
#     </tr>
#     <tr>
#       <th id="T_4defe_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_4defe_row6_col0" class="data row6 col0" >Ordinal Features</td>
#       <td id="T_4defe_row6_col1" class="data row6 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_4defe_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_4defe_row7_col0" class="data row7 col0" >High Cardinality Features</td>
#       <td id="T_4defe_row7_col1" class="data row7 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_4defe_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_4defe_row8_col0" class="data row8 col0" >High Cardinality Method</td>
#       <td id="T_4defe_row8_col1" class="data row8 col1" >None</td>
#     </tr>
#     <tr>
#       <th id="T_4defe_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_4defe_row9_col0" class="data row9 col0" >Transformed Train Set</td>
#       <td id="T_4defe_row9_col1" class="data row9 col1" >(936, 14)</td>
#     </tr>
#     <tr>
#       <th id="T_4defe_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_4defe_row10_col0" class="data row10 col0" >Transformed Test Set</td>
#       <td id="T_4defe_row10_col1" class="data row10 col1" >(402, 14)</td>
#     </tr>
#     <tr>
#       <th id="T_4defe_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_4defe_row11_col0" class="data row11 col0" >Shuffle Train-Test</td>
#       <td id="T_4defe_row11_col1" class="data row11 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_4defe_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_4defe_row12_col0" class="data row12 col0" >Stratify Train-Test</td>
#       <td id="T_4defe_row12_col1" class="data row12 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_4defe_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_4defe_row13_col0" class="data row13 col0" >Fold Generator</td>
#       <td id="T_4defe_row13_col1" class="data row13 col1" >KFold</td>
#     </tr>
#     <tr>
#       <th id="T_4defe_level0_row14" class="row_heading level0 row14" >14</th>
#       <td id="T_4defe_row14_col0" class="data row14 col0" >Fold Number</td>
#       <td id="T_4defe_row14_col1" class="data row14 col1" >10</td>
#     </tr>
#     <tr>
#       <th id="T_4defe_level0_row15" class="row_heading level0 row15" >15</th>
#       <td id="T_4defe_row15_col0" class="data row15 col0" >CPU Jobs</td>
#       <td id="T_4defe_row15_col1" class="data row15 col1" >-1</td>
#     </tr>
#     <tr>
#       <th id="T_4defe_level0_row16" class="row_heading level0 row16" >16</th>
#       <td id="T_4defe_row16_col0" class="data row16 col0" >Use GPU</td>
#       <td id="T_4defe_row16_col1" class="data row16 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_4defe_level0_row17" class="row_heading level0 row17" >17</th>
#       <td id="T_4defe_row17_col0" class="data row17 col0" >Log Experiment</td>
#       <td id="T_4defe_row17_col1" class="data row17 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_4defe_level0_row18" class="row_heading level0 row18" >18</th>
#       <td id="T_4defe_row18_col0" class="data row18 col0" >Experiment Name</td>
#       <td id="T_4defe_row18_col1" class="data row18 col1" >reg-default-name</td>
#     </tr>
#     <tr>
#       <th id="T_4defe_level0_row19" class="row_heading level0 row19" >19</th>
#       <td id="T_4defe_row19_col0" class="data row19 col0" >USI</td>
#       <td id="T_4defe_row19_col1" class="data row19 col1" >4597</td>
#     </tr>
#     <tr>
#       <th id="T_4defe_level0_row20" class="row_heading level0 row20" >20</th>
#       <td id="T_4defe_row20_col0" class="data row20 col0" >Imputation Type</td>
#       <td id="T_4defe_row20_col1" class="data row20 col1" >simple</td>
#     </tr>
#     <tr>
#       <th id="T_4defe_level0_row21" class="row_heading level0 row21" >21</th>
#       <td id="T_4defe_row21_col0" class="data row21 col0" >Iterative Imputation Iteration</td>
#       <td id="T_4defe_row21_col1" class="data row21 col1" >None</td>
#     </tr>
#     <tr>
#       <th id="T_4defe_level0_row22" class="row_heading level0 row22" >22</th>
#       <td id="T_4defe_row22_col0" class="data row22 col0" >Numeric Imputer</td>
#       <td id="T_4defe_row22_col1" class="data row22 col1" >mean</td>
#     </tr>
#     <tr>
#       <th id="T_4defe_level0_row23" class="row_heading level0 row23" >23</th>
#       <td id="T_4defe_row23_col0" class="data row23 col0" >Iterative Imputation Numeric Model</td>
#       <td id="T_4defe_row23_col1" class="data row23 col1" >None</td>
#     </tr>
#     <tr>
#       <th id="T_4defe_level0_row24" class="row_heading level0 row24" >24</th>
#       <td id="T_4defe_row24_col0" class="data row24 col0" >Categorical Imputer</td>
#       <td id="T_4defe_row24_col1" class="data row24 col1" >constant</td>
#     </tr>
#     <tr>
#       <th id="T_4defe_level0_row25" class="row_heading level0 row25" >25</th>
#       <td id="T_4defe_row25_col0" class="data row25 col0" >Iterative Imputation Categorical Model</td>
#       <td id="T_4defe_row25_col1" class="data row25 col1" >None</td>
#     </tr>
#     <tr>
#       <th id="T_4defe_level0_row26" class="row_heading level0 row26" >26</th>
#       <td id="T_4defe_row26_col0" class="data row26 col0" >Unknown Categoricals Handling</td>
#       <td id="T_4defe_row26_col1" class="data row26 col1" >least_frequent</td>
#     </tr>
#     <tr>
#       <th id="T_4defe_level0_row27" class="row_heading level0 row27" >27</th>
#       <td id="T_4defe_row27_col0" class="data row27 col0" >Normalize</td>
#       <td id="T_4defe_row27_col1" class="data row27 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_4defe_level0_row28" class="row_heading level0 row28" >28</th>
#       <td id="T_4defe_row28_col0" class="data row28 col0" >Normalize Method</td>
#       <td id="T_4defe_row28_col1" class="data row28 col1" >None</td>
#     </tr>
#     <tr>
#       <th id="T_4defe_level0_row29" class="row_heading level0 row29" >29</th>
#       <td id="T_4defe_row29_col0" class="data row29 col0" >Transformation</td>
#       <td id="T_4defe_row29_col1" class="data row29 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_4defe_level0_row30" class="row_heading level0 row30" >30</th>
#       <td id="T_4defe_row30_col0" class="data row30 col0" >Transformation Method</td>
#       <td id="T_4defe_row30_col1" class="da

# %%
# train model
best = compare_models()
# Out:
# <style type="text/css">
# #T_d0f80 th {
#   text-align: left;
# }
# #T_d0f80_row0_col0, #T_d0f80_row0_col6, #T_d0f80_row1_col0, #T_d0f80_row1_col1, #T_d0f80_row1_col2, #T_d0f80_row1_col3, #T_d0f80_row1_col4, #T_d0f80_row1_col5, #T_d0f80_row1_col6, #T_d0f80_row2_col0, #T_d0f80_row2_col1, #T_d0f80_row2_col2, #T_d0f80_row2_col3, #T_d0f80_row2_col4, #T_d0f80_row2_col5, #T_d0f80_row2_col6, #T_d0f80_row3_col0, #T_d0f80_row3_col1, #T_d0f80_row3_col2, #T_d0f80_row3_col3, #T_d0f80_row3_col4, #T_d0f80_row3_col5, #T_d0f80_row3_col6, #T_d0f80_row4_col0, #T_d0f80_row4_col1, #T_d0f80_row4_col2, #T_d0f80_row4_col3, #T_d0f80_row4_col4, #T_d0f80_row4_col5, #T_d0f80_row4_col6, #T_d0f80_row5_col0, #T_d0f80_row5_col1, #T_d0f80_row5_col2, #T_d0f80_row5_col3, #T_d0f80_row5_col4, #T_d0f80_row5_col5, #T_d0f80_row5_col6, #T_d0f80_row6_col0, #T_d0f80_row6_col1, #T_d0f80_row6_col2, #T_d0f80_row6_col3, #T_d0f80_row6_col4, #T_d0f80_row6_col5, #T_d0f80_row6_col6, #T_d0f80_row7_col0, #T_d0f80_row7_col1, #T_d0f80_row7_col2, #T_d0f80_row7_col3, #T_d0f80_row7_col4, #T_d0f80_row7_col5, #T_d0f80_row7_col6, #T_d0f80_row8_col0, #T_d0f80_row8_col1, #T_d0f80_row8_col2, #T_d0f80_row8_col3, #T_d0f80_row8_col4, #T_d0f80_row8_col5, #T_d0f80_row8_col6, #T_d0f80_row9_col0, #T_d0f80_row9_col1, #T_d0f80_row9_col2, #T_d0f80_row9_col3, #T_d0f80_row9_col4, #T_d0f80_row9_col5, #T_d0f80_row9_col6, #T_d0f80_row10_col0, #T_d0f80_row10_col1, #T_d0f80_row10_col2, #T_d0f80_row10_col3, #T_d0f80_row10_col4, #T_d0f80_row10_col5, #T_d0f80_row10_col6, #T_d0f80_row11_col0, #T_d0f80_row11_col1, #T_d0f80_row11_col2, #T_d0f80_row11_col3, #T_d0f80_row11_col4, #T_d0f80_row11_col5, #T_d0f80_row11_col6, #T_d0f80_row12_col0, #T_d0f80_row12_col1, #T_d0f80_row12_col2, #T_d0f80_row12_col3, #T_d0f80_row12_col4, #T_d0f80_row12_col5, #T_d0f80_row12_col6, #T_d0f80_row13_col0, #T_d0f80_row13_col1, #T_d0f80_row13_col2, #T_d0f80_row13_col3, #T_d0f80_row13_col4, #T_d0f80_row13_col5, #T_d0f80_row13_col6, #T_d0f80_row14_col0, #T_d0f80_row14_col1, #T_d0f80_row14_col2, #T_d0f80_row14_col3, #T_d0f80_row14_col4, #T_d0f80_row14_col5, #T_d0f80_row15_col0, #T_d0f80_row15_col1, #T_d0f80_row15_col2, #T_d0f80_row15_col3, #T_d0f80_row15_col4, #T_d0f80_row15_col5, #T_d0f80_row15_col6, #T_d0f80_row16_col0, #T_d0f80_row16_col1, #T_d0f80_row16_col2, #T_d0f80_row16_col3, #T_d0f80_row16_col4, #T_d0f80_row16_col5, #T_d0f80_row16_col6, #T_d0f80_row17_col0, #T_d0f80_row17_col1, #T_d0f80_row17_col2, #T_d0f80_row17_col3, #T_d0f80_row17_col4, #T_d0f80_row17_col5, #T_d0f80_row17_col6, #T_d0f80_row18_col0, #T_d0f80_row18_col1, #T_d0f80_row18_col2, #T_d0f80_row18_col3, #T_d0f80_row18_col4, #T_d0f80_row18_col5, #T_d0f80_row18_col6, #T_d0f80_row19_col0, #T_d0f80_row19_col1, #T_d0f80_row19_col2, #T_d0f80_row19_col3, #T_d0f80_row19_col4, #T_d0f80_row19_col5, #T_d0f80_row19_col6 {
#   text-align: left;
# }
# #T_d0f80_row0_col1, #T_d0f80_row0_col2, #T_d0f80_row0_col3, #T_d0f80_row0_col4, #T_d0f80_row0_col5, #T_d0f80_row14_col6 {
#   text-align: left;
#   background-color: yellow;
# }
# #T_d0f80_row0_col7, #T_d0f80_row1_col7, #T_d0f80_row2_col7, #T_d0f80_row3_col7, #T_d0f80_row4_col7, #T_d0f80_row5_col7, #T_d0f80_row6_col7, #T_d0f80_row7_col7, #T_d0f80_row10_col7, #T_d0f80_row11_col7, #T_d0f80_row12_col7, #T_d0f80_row13_col7, #T_d0f80_row14_col7, #T_d0f80_row16_col7, #T_d0f80_row18_col7, #T_d0f80_row19_col7 {
#   text-align: left;
#   background-color: lightgrey;
# }
# #T_d0f80_row8_col7, #T_d0f80_row9_col7, #T_d0f80_row15_col7, #T_d0f80_row17_col7 {
#   text-align: left;
#   background-color: yellow;
#   background-color: lightgrey;
# }
# </style>
# <table id="T_d0f80">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_d0f80_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_d0f80_level0_col1" class="col_heading level0 col1" >MAE</th>
#       <th id="T_d0f80_level0_col2" class="col_heading level0 col2" >MSE</th>
#       <th id="T_d0f80_level0_col3" class="col_heading level0 col3" >RMSE</th>
#       <th id="T_d0f80_level0_col4" class="col_heading level0 col4" >R2</th>
#       <th id="T_d0f80_level0_col5" class="col_heading level0 col5" >RMSLE</th>
#       <th id="T_d0f80_level0_col6" class="col_heading level0 col6" >MAPE</th>
#       <th id="T_d0f80_level0_col7" class="col_heading level0 col7" >TT (Sec)</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_d0f80_level0_row0" class="row_heading level0 row0" >gbr</th>
#       <td id="T_d0f80_row0_col0" class="data row0 col0" >Gradient Boosting Regressor</td>
#       <td id="T_d0f80_row0_col1" class="data row0 col1" >2702.7680</td>
#       <td id="T_d0f80_row0_col2" class="data row0 col2" >23242056.4409</td>
#       <td id="T_d0f80_row0_col3" class="data row0 col3" >4801.5704</td>
#       <td id="T_d0f80_row0_col4" class="data row0 col4" >0.8348</td>
#       <td id="T_d0f80_row0_col5" class="data row0 col5" >0.4397</td>
#       <td id="T_d0f80_row0_col6" class="data row0 col6" >0.3113</td>
#       <td id="T_d0f80_row0_col7" class="data row0 col7" >0.0500</td>
#     </tr>
#     <tr>
#       <th id="T_d0f80_level0_row1" class="row_heading level0 row1" >rf</th>
#       <td id="T_d0f80_row1_col0" class="data row1 col0" >Random Forest Regressor</td>
#       <td id="T_d0f80_row1_col1" class="data row1 col1" >2736.7455</td>
#       <td id="T_d0f80_row1_col2" class="data row1 col2" >24862762.2305</td>
#       <td id="T_d0f80_row1_col3" class="data row1 col3" >4970.6959</td>
#       <td id="T_d0f80_row1_col4" class="data row1 col4" >0.8213</td>
#       <td id="T_d0f80_row1_col5" class="data row1 col5" >0.4674</td>
#       <td id="T_d0f80_row1_col6" class="data row1 col6" >0.3294</td>
#       <td id="T_d0f80_row1_col7" class="data row1 col7" >0.1510</td>
#     </tr>
#     <tr>
#       <th id="T_d0f80_level0_row2" class="row_heading level0 row2" >catboost</th>
#       <td id="T_d0f80_row2_col0" class="data row2 col0" >CatBoost Regressor</td>
#       <td id="T_d0f80_row2_col1" class="data row2 col1" >2865.4462</td>
#       <td id="T_d0f80_row2_col2" class="data row2 col2" >25334554.7726</td>
#       <td id="T_d0f80_row2_col3" class="data row2 col3" >5017.8574</td>
#       <td id="T_d0f80_row2_col4" class="data row2 col4" >0.8193</td>
#       <td id="T_d0f80_row2_col5" class="data row2 col5" >0.4774</td>
#       <td id="T_d0f80_row2_col6" class="data row2 col6" >0.3419</td>
#       <td id="T_d0f80_row2_col7" class="data row2 col7" >0.7490</td>
#     </tr>
#     <tr>
#       <th id="T_d0f80_level0_row3" class="row_heading level0 row3" >lightgbm</th>
#       <td id="T_d0f80_row3_col0" class="data row3 col0" >Light Gradient Boosting Machine</td>
#       <td id="T_d0f80_row3_col1" class="data row3 col1" >2959.5584</td>
#       <td id="T_d0f80_row3_col2" class="data row3 col2" >25236477.0456</td>
#       <td id="T_d0f80_row3_col3" class="data row3 col3" >5013.0892</td>
#       <td id="T_d0f80_row3_col4" class="data row3 col4" >0.8171</td>
#       <td id="T_d0f80_row3_col5" class="data row3 col5" >0.5427</td>
#       <td id="T_d0f80_row3_col6" class="data row3 col6" >0.3685</td>
#       <td id="T_d0f80_row3_col7" class="data row3 col7" >0.0330</td>
#     </tr>
#     <tr>
#       <th id="T_d0f80_level0_row4" class="row_heading level0 row4" >ada</th>
#       <td id="T_d0f80_row4_col0" class="data row4 col0" >AdaBoost Regressor</td>
#       <td id="T_d0f80_row4_col1" class="data row4 col1" >4162.2323</td>
#       <td id="T_d0f80_row4_col2" class="data row4 col2" >28328260.0955</td>
#       <td id="T_d0f80_row4_col3" class="data row4 col3" >5316.6146</td>
#       <td id="T_d0f80_row4_col4" class="data row4 col4" >0.7985</td>
#       <td id="T_d0f80_row4_col5" class="data row4 col5" >0.6349</td>
#       <td id="T_d0f80_row4_col6" class="data row4 col6" >0.7263</td>
#       <td id="T_d0f80_row4_col7" class="data row4 col7" >0.0130</td>
#     </tr>
#     <tr>
#       <th id="T_d0f80_level0_row5" class="row_heading level0 row5" >et</th>
#       <td id="T_d0f80_row5_col0" class="data row5 col0" >Extra Trees Regressor</td>
#       <td id="T_d0f80_row5_col1" class="data row5 col1" >2814.2964</td>
#       <td id="T_d0f80_row5_col2" class="data row5 col2" >2

# %% [markdown]
# ###

# %%
def predict_charges(age, bmi,sex,smoker,region,children):
    df = pd.DataFrame.from_dict({'sex': [sex], 'age': [age], 'smoker': [smoker],'bmi':[bmi],'region':[region],'children':[children]})
    
    pred = predict_model(best, df)['Label'][0]
    
    #df = encode_attributes(df)
    #pred = blend_saved.predict(df).tolist()[0]
    return 'Cargos sanitarios : '+str(pred)

# %%
import gradio as gr

sex = gr.inputs.Radio(['female', 'male'], label='sex')
smoker = gr.inputs.Radio(['no', 'yes'], label='smoker')
children = gr.inputs.Radio([2, 3, 1, 4, 5, 0], label='children')
region = gr.inputs.Radio(['northeast', 'southeast', 'northwest', 'southwest'], 
                         label='region')

age = gr.inputs.Slider(minimum=15, maximum=75, default=16, label='age')
bmi = gr.inputs.Slider(minimum=15, maximum=60, default=16, label='bmi')

# %%
gr.Interface(predict_charges, inputs=[age, bmi,sex,smoker,region,children], 
             outputs='label',
             title='Medical Insurance Cost Prediction',
             capture_session=True,
             live=True).launch();
# Out:
# Running on local URL:  http://127.0.0.1:7860/
#
# To create a public link, set `share=True` in `launch()`.
#         <iframe
#             width="900"
#             height="500"
#             src="http://127.0.0.1:7860/"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>
