# %% [markdown]
# # Regression Models with Pycaret

# %% [markdown]
# #### Get data

# %%
from pycaret.regression import *

# %%
# load the dataset from pycaret
from pycaret.datasets import get_data
dataset = get_data('diamond')
# Out:
#    Carat Weight    Cut Color Clarity Polish Symmetry Report  Price
# 0          1.10  Ideal     H     SI1     VG       EX    GIA   5169
# 1          0.83  Ideal     H     VS1     ID       ID   AGSL   3470
# 2          0.85  Ideal     H     SI1     EX       EX    GIA   3183
# 3          0.91  Ideal     E     SI1     VG       VG    GIA   4370
# 4          0.83  Ideal     G     SI1     EX       EX    GIA   3171

# %% [markdown]
# #### EDA

# %%
dataset = get_data('diamond')
# Out:
#    Carat Weight    Cut Color Clarity Polish Symmetry Report  Price
# 0          1.10  Ideal     H     SI1     VG       EX    GIA   5169
# 1          0.83  Ideal     H     VS1     ID       ID   AGSL   3470
# 2          0.85  Ideal     H     SI1     EX       EX    GIA   3183
# 3          0.91  Ideal     E     SI1     VG       VG    GIA   4370
# 4          0.83  Ideal     G     SI1     EX       EX    GIA   3171

# %%
data = dataset.sample(frac=0.9, random_state=786)
data_unseen = dataset.drop(data.index)

data.reset_index(drop=True, inplace=True)
data_unseen.reset_index(drop=True, inplace=True)

print('Data for Modeling: ' + str(data.shape))
print('Unseen Data For Predictions ' + str(data_unseen.shape))
# Out:
# Data for Modeling: (5400, 8)
# Unseen Data For Predictions (600, 8)

# %% [markdown]
# #### Preprocessing

# %%
# initialize setup

exp_reg102 = setup(data = data, target = 'Price', 
                   session_id=123,
                   normalize = True, 
                   transformation = True, transform_target = True, 
                  combine_rare_levels = True, rare_level_threshold = 0.05,
                  remove_multicollinearity = True, multicollinearity_threshold = 0.95, 
                  bin_numeric_features = ['Carat Weight'],
                  log_experiment = True, experiment_name = 'diamond1',
                  silent=True)
# Out:
# <style type="text/css">
# #T_053d0_row17_col1, #T_053d0_row27_col1, #T_053d0_row29_col1, #T_053d0_row35_col1, #T_053d0_row37_col1, #T_053d0_row40_col1, #T_053d0_row42_col1, #T_053d0_row56_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_053d0">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_053d0_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_053d0_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_053d0_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_053d0_row0_col0" class="data row0 col0" >session_id</td>
#       <td id="T_053d0_row0_col1" class="data row0 col1" >123</td>
#     </tr>
#     <tr>
#       <th id="T_053d0_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_053d0_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_053d0_row1_col1" class="data row1 col1" >Price</td>
#     </tr>
#     <tr>
#       <th id="T_053d0_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_053d0_row2_col0" class="data row2 col0" >Original Data</td>
#       <td id="T_053d0_row2_col1" class="data row2 col1" >(5400, 8)</td>
#     </tr>
#     <tr>
#       <th id="T_053d0_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_053d0_row3_col0" class="data row3 col0" >Missing Values</td>
#       <td id="T_053d0_row3_col1" class="data row3 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_053d0_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_053d0_row4_col0" class="data row4 col0" >Numeric Features</td>
#       <td id="T_053d0_row4_col1" class="data row4 col1" >1</td>
#     </tr>
#     <tr>
#       <th id="T_053d0_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_053d0_row5_col0" class="data row5 col0" >Categorical Features</td>
#       <td id="T_053d0_row5_col1" class="data row5 col1" >6</td>
#     </tr>
#     <tr>
#       <th id="T_053d0_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_053d0_row6_col0" class="data row6 col0" >Ordinal Features</td>
#       <td id="T_053d0_row6_col1" class="data row6 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_053d0_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_053d0_row7_col0" class="data row7 col0" >High Cardinality Features</td>
#       <td id="T_053d0_row7_col1" class="data row7 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_053d0_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_053d0_row8_col0" class="data row8 col0" >High Cardinality Method</td>
#       <td id="T_053d0_row8_col1" class="data row8 col1" >None</td>
#     </tr>
#     <tr>
#       <th id="T_053d0_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_053d0_row9_col0" class="data row9 col0" >Transformed Train Set</td>
#       <td id="T_053d0_row9_col1" class="data row9 col1" >(3779, 39)</td>
#     </tr>
#     <tr>
#       <th id="T_053d0_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_053d0_row10_col0" class="data row10 col0" >Transformed Test Set</td>
#       <td id="T_053d0_row10_col1" class="data row10 col1" >(1621, 39)</td>
#     </tr>
#     <tr>
#       <th id="T_053d0_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_053d0_row11_col0" class="data row11 col0" >Shuffle Train-Test</td>
#       <td id="T_053d0_row11_col1" class="data row11 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_053d0_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_053d0_row12_col0" class="data row12 col0" >Stratify Train-Test</td>
#       <td id="T_053d0_row12_col1" class="data row12 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_053d0_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_053d0_row13_col0" class="data row13 col0" >Fold Generator</td>
#       <td id="T_053d0_row13_col1" class="data row13 col1" >KFold</td>
#     </tr>
#     <tr>
#       <th id="T_053d0_level0_row14" class="row_heading level0 row14" >14</th>
#       <td id="T_053d0_row14_col0" class="data row14 col0" >Fold Number</td>
#       <td id="T_053d0_row14_col1" class="data row14 col1" >10</td>
#     </tr>
#     <tr>
#       <th id="T_053d0_level0_row15" class="row_heading level0 row15" >15</th>
#       <td id="T_053d0_row15_col0" class="data row15 col0" >CPU Jobs</td>
#       <td id="T_053d0_row15_col1" class="data row15 col1" >-1</td>
#     </tr>
#     <tr>
#       <th id="T_053d0_level0_row16" class="row_heading level0 row16" >16</th>
#       <td id="T_053d0_row16_col0" class="data row16 col0" >Use GPU</td>
#       <td id="T_053d0_row16_col1" class="data row16 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_053d0_level0_row17" class="row_heading level0 row17" >17</th>
#       <td id="T_053d0_row17_col0" class="data row17 col0" >Log Experiment</td>
#       <td id="T_053d0_row17_col1" class="data row17 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_053d0_level0_row18" class="row_heading level0 row18" >18</th>
#       <td id="T_053d0_row18_col0" class="data row18 col0" >Experiment Name</td>
#       <td id="T_053d0_row18_col1" class="data row18 col1" >diamond1</td>
#     </tr>
#     <tr>
#       <th id="T_053d0_level0_row19" class="row_heading level0 row19" >19</th>
#       <td id="T_053d0_row19_col0" class="data row19 col0" >USI</td>
#       <td id="T_053d0_row19_col1" class="data row19 col1" >6dfe</td>
#     </tr>
#     <tr>
#       <th id="T_053d0_level0_row20" class="row_heading level0 row20" >20</th>
#       <td id="T_053d0_row20_col0" class="data row20 col0" >Imputation Type</td>
#       <td id="T_053d0_row20_col1" class="data row20 col1" >simple</td>
#     </tr>
#     <tr>
#       <th id="T_053d0_level0_row21" class="row_heading level0 row21" >21</th>
#       <td id="T_053d0_row21_col0" class="data row21 col0" >Iterative Imputation Iteration</td>
#       <td id="T_053d0_row21_col1" class="data row21 col1" >None</td>
#     </tr>
#     <tr>
#       <th id="T_053d0_level0_row22" class="row_heading level0 row22" >22</th>
#       <td id="T_053d0_row22_col0" class="data row22 col0" >Numeric Imputer</td>
#       <td id="T_053d0_row22_col1" class="data row22 col1" >mean</td>
#     </tr>
#     <tr>
#       <th id="T_053d0_level0_row23" class="row_heading level0 row23" >23</th>
#       <td id="T_053d0_row23_col0" class="data row23 col0" >Iterative Imputation Numeric Model</td>
#       <td id="T_053d0_row23_col1" class="data row23 col1" >None</td>
#     </tr>
#     <tr>
#       <th id="T_053d0_level0_row24" class="row_heading level0 row24" >24</th>
#       <td id="T_053d0_row24_col0" class="data row24 col0" >Categorical Imputer</td>
#       <td id="T_053d0_row24_col1" class="data row24 col1" >constant</td>
#     </tr>
#     <tr>
#       <th id="T_053d0_level0_row25" class="row_heading level0 row25" >25</th>
#       <td id="T_053d0_row25_col0" class="data row25 col0" >Iterative Imputation Categorical Model</td>
#       <td id="T_053d0_row25_col1" class="data row25 col1" >None</td>
#     </tr>
#     <tr>
#       <th id="T_053d0_level0_row26" class="row_heading level0 row26" >26</th>
#       <td id="T_053d0_row26_col0" class="data row26 col0" >Unknown Categoricals Handling</td>
#       <td id="T_053d0_row26_col1" class="data row26 col1" >least_frequent</td>
#     </tr>
#     <tr>
#       <th id="T_053d0_level0_row27" class="row_heading level0 row27" >27</th>
#       <td id="T_053d0_row27_col0" class="data row27 col0" >Normalize</td>
#       <td id="T_053d0_row27_col1" class="data row27 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_053d0_level0_row28" class="row_heading level0 row28" >28</th>
#       <td id="T_053d0_row28_col0" class="data row28 col0" >Normalize Method</td>
#       <td id="T_053d0_row28_col1" class="data row28 col1" >zscore</td>
#     </tr>
#     <tr>
#       <th id="T_053d0_level0_row29" class="row_heading level0 row29" >29</th>
#       <td id="T_053d0_row29_col0" class="data row29 col0" >Transformation</td>
#       <td id="T_053d0_row29_col1" class="data row29 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_053d0_level0_row30" class="row_heading level0 row30"
# 2022/08/13 17:37:09 INFO mlflow.tracking.fluent: Experiment with name 'diamond1' does not exist. Creating a new experiment.

# %% [markdown]
# #### Model Training

# %%
best_model = compare_models(exclude = ['ransac'])
# Out:
# <style type="text/css">
# #T_e2fb8 th {
#   text-align: left;
# }
# #T_e2fb8_row0_col0, #T_e2fb8_row1_col0, #T_e2fb8_row1_col1, #T_e2fb8_row1_col2, #T_e2fb8_row1_col3, #T_e2fb8_row1_col4, #T_e2fb8_row1_col5, #T_e2fb8_row1_col6, #T_e2fb8_row2_col0, #T_e2fb8_row2_col1, #T_e2fb8_row2_col2, #T_e2fb8_row2_col3, #T_e2fb8_row2_col4, #T_e2fb8_row2_col5, #T_e2fb8_row2_col6, #T_e2fb8_row3_col0, #T_e2fb8_row3_col1, #T_e2fb8_row3_col2, #T_e2fb8_row3_col3, #T_e2fb8_row3_col4, #T_e2fb8_row3_col5, #T_e2fb8_row3_col6, #T_e2fb8_row4_col0, #T_e2fb8_row4_col1, #T_e2fb8_row4_col2, #T_e2fb8_row4_col3, #T_e2fb8_row4_col4, #T_e2fb8_row4_col5, #T_e2fb8_row4_col6, #T_e2fb8_row5_col0, #T_e2fb8_row5_col1, #T_e2fb8_row5_col2, #T_e2fb8_row5_col3, #T_e2fb8_row5_col4, #T_e2fb8_row5_col5, #T_e2fb8_row5_col6, #T_e2fb8_row6_col0, #T_e2fb8_row6_col1, #T_e2fb8_row6_col2, #T_e2fb8_row6_col3, #T_e2fb8_row6_col4, #T_e2fb8_row6_col5, #T_e2fb8_row6_col6, #T_e2fb8_row7_col0, #T_e2fb8_row7_col1, #T_e2fb8_row7_col2, #T_e2fb8_row7_col3, #T_e2fb8_row7_col4, #T_e2fb8_row7_col5, #T_e2fb8_row7_col6, #T_e2fb8_row8_col0, #T_e2fb8_row8_col1, #T_e2fb8_row8_col2, #T_e2fb8_row8_col3, #T_e2fb8_row8_col4, #T_e2fb8_row8_col5, #T_e2fb8_row8_col6, #T_e2fb8_row9_col0, #T_e2fb8_row9_col1, #T_e2fb8_row9_col2, #T_e2fb8_row9_col3, #T_e2fb8_row9_col4, #T_e2fb8_row9_col5, #T_e2fb8_row9_col6, #T_e2fb8_row10_col0, #T_e2fb8_row10_col1, #T_e2fb8_row10_col2, #T_e2fb8_row10_col3, #T_e2fb8_row10_col4, #T_e2fb8_row10_col5, #T_e2fb8_row10_col6, #T_e2fb8_row11_col0, #T_e2fb8_row11_col1, #T_e2fb8_row11_col2, #T_e2fb8_row11_col3, #T_e2fb8_row11_col4, #T_e2fb8_row11_col5, #T_e2fb8_row11_col6, #T_e2fb8_row12_col0, #T_e2fb8_row12_col1, #T_e2fb8_row12_col2, #T_e2fb8_row12_col3, #T_e2fb8_row12_col4, #T_e2fb8_row12_col5, #T_e2fb8_row12_col6, #T_e2fb8_row13_col0, #T_e2fb8_row13_col1, #T_e2fb8_row13_col2, #T_e2fb8_row13_col3, #T_e2fb8_row13_col4, #T_e2fb8_row13_col5, #T_e2fb8_row13_col6, #T_e2fb8_row14_col0, #T_e2fb8_row14_col1, #T_e2fb8_row14_col2, #T_e2fb8_row14_col3, #T_e2fb8_row14_col4, #T_e2fb8_row14_col5, #T_e2fb8_row14_col6, #T_e2fb8_row15_col0, #T_e2fb8_row15_col1, #T_e2fb8_row15_col2, #T_e2fb8_row15_col3, #T_e2fb8_row15_col4, #T_e2fb8_row15_col5, #T_e2fb8_row15_col6, #T_e2fb8_row16_col0, #T_e2fb8_row16_col1, #T_e2fb8_row16_col2, #T_e2fb8_row16_col3, #T_e2fb8_row16_col4, #T_e2fb8_row16_col5, #T_e2fb8_row16_col6, #T_e2fb8_row17_col0, #T_e2fb8_row17_col1, #T_e2fb8_row17_col2, #T_e2fb8_row17_col3, #T_e2fb8_row17_col4, #T_e2fb8_row17_col5, #T_e2fb8_row17_col6, #T_e2fb8_row18_col0, #T_e2fb8_row18_col1, #T_e2fb8_row18_col2, #T_e2fb8_row18_col3, #T_e2fb8_row18_col4, #T_e2fb8_row18_col5, #T_e2fb8_row18_col6 {
#   text-align: left;
# }
# #T_e2fb8_row0_col1, #T_e2fb8_row0_col2, #T_e2fb8_row0_col3, #T_e2fb8_row0_col4, #T_e2fb8_row0_col5, #T_e2fb8_row0_col6 {
#   text-align: left;
#   background-color: yellow;
# }
# #T_e2fb8_row0_col7, #T_e2fb8_row1_col7, #T_e2fb8_row2_col7, #T_e2fb8_row3_col7, #T_e2fb8_row4_col7, #T_e2fb8_row5_col7, #T_e2fb8_row6_col7, #T_e2fb8_row7_col7, #T_e2fb8_row8_col7, #T_e2fb8_row9_col7, #T_e2fb8_row10_col7, #T_e2fb8_row11_col7, #T_e2fb8_row12_col7, #T_e2fb8_row13_col7, #T_e2fb8_row15_col7, #T_e2fb8_row16_col7, #T_e2fb8_row17_col7, #T_e2fb8_row18_col7 {
#   text-align: left;
#   background-color: lightgrey;
# }
# #T_e2fb8_row14_col7 {
#   text-align: left;
#   background-color: yellow;
#   background-color: lightgrey;
# }
# </style>
# <table id="T_e2fb8">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_e2fb8_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_e2fb8_level0_col1" class="col_heading level0 col1" >MAE</th>
#       <th id="T_e2fb8_level0_col2" class="col_heading level0 col2" >MSE</th>
#       <th id="T_e2fb8_level0_col3" class="col_heading level0 col3" >RMSE</th>
#       <th id="T_e2fb8_level0_col4" class="col_heading level0 col4" >R2</th>
#       <th id="T_e2fb8_level0_col5" class="col_heading level0 col5" >RMSLE</th>
#       <th id="T_e2fb8_level0_col6" class="col_heading level0 col6" >MAPE</th>
#       <th id="T_e2fb8_level0_col7" class="col_heading level0 col7" >TT (Sec)</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_e2fb8_level0_row0" class="row_heading level0 row0" >catboost</th>
#       <td id="T_e2fb8_row0_col0" class="data row0 col0" >CatBoost Regressor</td>
#       <td id="T_e2fb8_row0_col1" class="data row0 col1" >712.8586</td>
#       <td id="T_e2fb8_row0_col2" class="data row0 col2" >2545528.9595</td>
#       <td id="T_e2fb8_row0_col3" class="data row0 col3" >1556.7696</td>
#       <td id="T_e2fb8_row0_col4" class="data row0 col4" >0.9749</td>
#       <td id="T_e2fb8_row0_col5" class="data row0 col5" >0.0752</td>
#       <td id="T_e2fb8_row0_col6" class="data row0 col6" >0.0548</td>
#       <td id="T_e2fb8_row0_col7" class="data row0 col7" >1.0370</td>
#     </tr>
#     <tr>
#       <th id="T_e2fb8_level0_row1" class="row_heading level0 row1" >xgboost</th>
#       <td id="T_e2fb8_row1_col0" class="data row1 col0" >Extreme Gradient Boosting</td>
#       <td id="T_e2fb8_row1_col1" class="data row1 col1" >775.3886</td>
#       <td id="T_e2fb8_row1_col2" class="data row1 col2" >2808499.5695</td>
#       <td id="T_e2fb8_row1_col3" class="data row1 col3" >1640.2406</td>
#       <td id="T_e2fb8_row1_col4" class="data row1 col4" >0.9728</td>
#       <td id="T_e2fb8_row1_col5" class="data row1 col5" >0.0807</td>
#       <td id="T_e2fb8_row1_col6" class="data row1 col6" >0.0589</td>
#       <td id="T_e2fb8_row1_col7" class="data row1 col7" >0.3300</td>
#     </tr>
#     <tr>
#       <th id="T_e2fb8_level0_row2" class="row_heading level0 row2" >lightgbm</th>
#       <td id="T_e2fb8_row2_col0" class="data row2 col0" >Light Gradient Boosting Machine</td>
#       <td id="T_e2fb8_row2_col1" class="data row2 col1" >766.0853</td>
#       <td id="T_e2fb8_row2_col2" class="data row2 col2" >3116466.5642</td>
#       <td id="T_e2fb8_row2_col3" class="data row2 col3" >1704.0975</td>
#       <td id="T_e2fb8_row2_col4" class="data row2 col4" >0.9704</td>
#       <td id="T_e2fb8_row2_col5" class="data row2 col5" >0.0799</td>
#       <td id="T_e2fb8_row2_col6" class="data row2 col6" >0.0576</td>
#       <td id="T_e2fb8_row2_col7" class="data row2 col7" >0.0680</td>
#     </tr>
#     <tr>
#       <th id="T_e2fb8_level0_row3" class="row_heading level0 row3" >rf</th>
#       <td id="T_e2fb8_row3_col0" class="data row3 col0" >Random Forest Regressor</td>
#       <td id="T_e2fb8_row3_col1" class="data row3 col1" >850.2817</td>
#       <td id="T_e2fb8_row3_col2" class="data row3 col2" >3268110.2457</td>
#       <td id="T_e2fb8_row3_col3" class="data row3 col3" >1770.5503</td>
#       <td id="T_e2fb8_row3_col4" class="data row3 col4" >0.9686</td>
#       <td id="T_e2fb8_row3_col5" class="data row3 col5" >0.0904</td>
#       <td id="T_e2fb8_row3_col6" class="data row3 col6" >0.0657</td>
#       <td id="T_e2fb8_row3_col7" class="data row3 col7" >0.4600</td>
#     </tr>
#     <tr>
#       <th id="T_e2fb8_level0_row4" class="row_heading level0 row4" >huber</th>
#       <td id="T_e2fb8_row4_col0" class="data row4 col0" >Huber Regressor</td>
#       <td id="T_e2fb8_row4_col1" class="data row4 col1" >940.6199</td>
#       <td id="T_e2fb8_row4_col2" class="data row4 col2" >3651906.6533</td>
#       <td id="T_e2fb8_row4_col3" class="data row4 col3" >1891.7126</td>
#       <td id="T_e2fb8_row4_col4" class="data row4 col4" >0.9640</td>
#       <td id="T_e2fb8_row4_col5" class="data row4 col5" >0.0972</td>
#       <td id="T_e2fb8_row4_col6" class="data row4 col6" >0.0708</td>
#       <td id="T_e2fb8_row4_col7" class="data row4 col7" >0.1350</td>
#     </tr>
#     <tr>
#       <th id="T_e2fb8_level0_row5" class="row_heading level0 row5" >ridge</th>
#       <td id="T_e2fb8_row5_col0" class="data row5 col0" >Ridge Regression</td>
#       <td id="T_e2fb8_row5_col1" class="data row5 col1" >952.2538</td>
#       <td id="T_e2fb8_row5_col2" class="data row5 col2" >3846277.6391</td>
#       <td id="T_e2fb8_row5_col3" class="data row5 col3" >1934.6314</td>
#       <td id="T_e2fb8_row5_col4" class="data row5 col4" >0.9624</td>
#       <td id="T_e2fb8_

# %%
tuned_best = tune_model(best_model)
# Out:
# <style type="text/css">
# #T_f7d56_row10_col0, #T_f7d56_row10_col1, #T_f7d56_row10_col2, #T_f7d56_row10_col3, #T_f7d56_row10_col4, #T_f7d56_row10_col5 {
#   background: yellow;
# }
# </style>
# <table id="T_f7d56">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_f7d56_level0_col0" class="col_heading level0 col0" >MAE</th>
#       <th id="T_f7d56_level0_col1" class="col_heading level0 col1" >MSE</th>
#       <th id="T_f7d56_level0_col2" class="col_heading level0 col2" >RMSE</th>
#       <th id="T_f7d56_level0_col3" class="col_heading level0 col3" >R2</th>
#       <th id="T_f7d56_level0_col4" class="col_heading level0 col4" >RMSLE</th>
#       <th id="T_f7d56_level0_col5" class="col_heading level0 col5" >MAPE</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Fold</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_f7d56_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_f7d56_row0_col0" class="data row0 col0" >685.7048</td>
#       <td id="T_f7d56_row0_col1" class="data row0 col1" >1454022.1693</td>
#       <td id="T_f7d56_row0_col2" class="data row0 col2" >1205.8284</td>
#       <td id="T_f7d56_row0_col3" class="data row0 col3" >0.9840</td>
#       <td id="T_f7d56_row0_col4" class="data row0 col4" >0.0763</td>
#       <td id="T_f7d56_row0_col5" class="data row0 col5" >0.0555</td>
#     </tr>
#     <tr>
#       <th id="T_f7d56_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_f7d56_row1_col0" class="data row1 col0" >776.8339</td>
#       <td id="T_f7d56_row1_col1" class="data row1 col1" >3534614.1994</td>
#       <td id="T_f7d56_row1_col2" class="data row1 col2" >1880.0570</td>
#       <td id="T_f7d56_row1_col3" class="data row1 col3" >0.9729</td>
#       <td id="T_f7d56_row1_col4" class="data row1 col4" >0.0729</td>
#       <td id="T_f7d56_row1_col5" class="data row1 col5" >0.0541</td>
#     </tr>
#     <tr>
#       <th id="T_f7d56_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_f7d56_row2_col0" class="data row2 col0" >747.0628</td>
#       <td id="T_f7d56_row2_col1" class="data row2 col1" >2345496.4829</td>
#       <td id="T_f7d56_row2_col2" class="data row2 col2" >1531.5014</td>
#       <td id="T_f7d56_row2_col3" class="data row2 col3" >0.9785</td>
#       <td id="T_f7d56_row2_col4" class="data row2 col4" >0.0753</td>
#       <td id="T_f7d56_row2_col5" class="data row2 col5" >0.0556</td>
#     </tr>
#     <tr>
#       <th id="T_f7d56_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_f7d56_row3_col0" class="data row3 col0" >688.5715</td>
#       <td id="T_f7d56_row3_col1" class="data row3 col1" >1516384.9206</td>
#       <td id="T_f7d56_row3_col2" class="data row3 col2" >1231.4158</td>
#       <td id="T_f7d56_row3_col3" class="data row3 col3" >0.9833</td>
#       <td id="T_f7d56_row3_col4" class="data row3 col4" >0.0719</td>
#       <td id="T_f7d56_row3_col5" class="data row3 col5" >0.0542</td>
#     </tr>
#     <tr>
#       <th id="T_f7d56_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_f7d56_row4_col0" class="data row4 col0" >740.9562</td>
#       <td id="T_f7d56_row4_col1" class="data row4 col1" >4576693.8234</td>
#       <td id="T_f7d56_row4_col2" class="data row4 col2" >2139.3209</td>
#       <td id="T_f7d56_row4_col3" class="data row4 col3" >0.9429</td>
#       <td id="T_f7d56_row4_col4" class="data row4 col4" >0.0787</td>
#       <td id="T_f7d56_row4_col5" class="data row4 col5" >0.0554</td>
#     </tr>
#     <tr>
#       <th id="T_f7d56_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_f7d56_row5_col0" class="data row5 col0" >764.6585</td>
#       <td id="T_f7d56_row5_col1" class="data row5 col1" >3856632.1318</td>
#       <td id="T_f7d56_row5_col2" class="data row5 col2" >1963.8310</td>
#       <td id="T_f7d56_row5_col3" class="data row5 col3" >0.9671</td>
#       <td id="T_f7d56_row5_col4" class="data row5 col4" >0.0759</td>
#       <td id="T_f7d56_row5_col5" class="data row5 col5" >0.0541</td>
#     </tr>
#     <tr>
#       <th id="T_f7d56_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_f7d56_row6_col0" class="data row6 col0" >814.5372</td>
#       <td id="T_f7d56_row6_col1" class="data row6 col1" >3033960.1293</td>
#       <td id="T_f7d56_row6_col2" class="data row6 col2" >1741.8267</td>
#       <td id="T_f7d56_row6_col3" class="data row6 col3" >0.9715</td>
#       <td id="T_f7d56_row6_col4" class="data row6 col4" >0.0819</td>
#       <td id="T_f7d56_row6_col5" class="data row6 col5" >0.0594</td>
#     </tr>
#     <tr>
#       <th id="T_f7d56_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_f7d56_row7_col0" class="data row7 col0" >675.5092</td>
#       <td id="T_f7d56_row7_col1" class="data row7 col1" >1501088.8156</td>
#       <td id="T_f7d56_row7_col2" class="data row7 col2" >1225.1893</td>
#       <td id="T_f7d56_row7_col3" class="data row7 col3" >0.9810</td>
#       <td id="T_f7d56_row7_col4" class="data row7 col4" >0.0752</td>
#       <td id="T_f7d56_row7_col5" class="data row7 col5" >0.0545</td>
#     </tr>
#     <tr>
#       <th id="T_f7d56_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_f7d56_row8_col0" class="data row8 col0" >695.6744</td>
#       <td id="T_f7d56_row8_col1" class="data row8 col1" >1692338.1281</td>
#       <td id="T_f7d56_row8_col2" class="data row8 col2" >1300.8990</td>
#       <td id="T_f7d56_row8_col3" class="data row8 col3" >0.9834</td>
#       <td id="T_f7d56_row8_col4" class="data row8 col4" >0.0727</td>
#       <td id="T_f7d56_row8_col5" class="data row8 col5" >0.0549</td>
#     </tr>
#     <tr>
#       <th id="T_f7d56_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_f7d56_row9_col0" class="data row9 col0" >769.9651</td>
#       <td id="T_f7d56_row9_col1" class="data row9 col1" >2839006.1183</td>
#       <td id="T_f7d56_row9_col2" class="data row9 col2" >1684.9350</td>
#       <td id="T_f7d56_row9_col3" class="data row9 col3" >0.9730</td>
#       <td id="T_f7d56_row9_col4" class="data row9 col4" >0.0865</td>
#       <td id="T_f7d56_row9_col5" class="data row9 col5" >0.0601</td>
#     </tr>
#     <tr>
#       <th id="T_f7d56_level0_row10" class="row_heading level0 row10" >Mean</th>
#       <td id="T_f7d56_row10_col0" class="data row10 col0" >735.9474</td>
#       <td id="T_f7d56_row10_col1" class="data row10 col1" >2635023.6919</td>
#       <td id="T_f7d56_row10_col2" class="data row10 col2" >1590.4804</td>
#       <td id="T_f7d56_row10_col3" class="data row10 col3" >0.9738</td>
#       <td id="T_f7d56_row10_col4" class="data row10 col4" >0.0767</td>
#       <td id="T_f7d56_row10_col5" class="data row10 col5" >0.0558</td>
#     </tr>
#     <tr>
#       <th id="T_f7d56_level0_row11" class="row_heading level0 row11" >Std</th>
#       <td id="T_f7d56_row11_col0" class="data row11 col0" >44.7456</td>
#       <td id="T_f7d56_row11_col1" class="data row11 col1" >1057205.7487</td>
#       <td id="T_f7d56_row11_col2" class="data row11 col2" >324.6470</td>
#       <td id="T_f7d56_row11_col3" class="data row11 col3" >0.0117</td>
#       <td id="T_f7d56_row11_col4" class="data row11 col4" >0.0043</td>
#       <td id="T_f7d56_row11_col5" class="data row11 col5" >0.0021</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# #### Individual model training

# %%
lightgbm = create_model('lightgbm')
# Out:
# <style type="text/css">
# #T_3e34f_row10_col0, #T_3e34f_row10_col1, #T_3e34f_row10_col2, #T_3e34f_row10_col3, #T_3e34f_row10_col4, #T_3e34f_row10_col5 {
#   background: yellow;
# }
# </style>
# <table id="T_3e34f">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_3e34f_level0_col0" class="col_heading level0 col0" >MAE</th>
#       <th id="T_3e34f_level0_col1" class="col_heading level0 col1" >MSE</th>
#       <th id="T_3e34f_level0_col2" class="col_heading level0 col2" >RMSE</th>
#       <th id="T_3e34f_level0_col3" class="col_heading level0 col3" >R2</th>
#       <th id="T_3e34f_level0_col4" class="col_heading level0 col4" >RMSLE</th>
#       <th id="T_3e34f_level0_col5" class="col_heading level0 col5" >MAPE</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Fold</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_3e34f_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_3e34f_row0_col0" class="data row0 col0" >762.0852</td>
#       <td id="T_3e34f_row0_col1" class="data row0 col1" >2398824.3414</td>
#       <td id="T_3e34f_row0_col2" class="data row0 col2" >1548.8138</td>
#       <td id="T_3e34f_row0_col3" class="data row0 col3" >0.9737</td>
#       <td id="T_3e34f_row0_col4" class="data row0 col4" >0.0805</td>
#       <td id="T_3e34f_row0_col5" class="data row0 col5" >0.0581</td>
#     </tr>
#     <tr>
#       <th id="T_3e34f_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_3e34f_row1_col0" class="data row1 col0" >891.4400</td>
#       <td id="T_3e34f_row1_col1" class="data row1 col1" >5694025.6674</td>
#       <td id="T_3e34f_row1_col2" class="data row1 col2" >2386.2158</td>
#       <td id="T_3e34f_row1_col3" class="data row1 col3" >0.9564</td>
#       <td id="T_3e34f_row1_col4" class="data row1 col4" >0.0790</td>
#       <td id="T_3e34f_row1_col5" class="data row1 col5" >0.0588</td>
#     </tr>
#     <tr>
#       <th id="T_3e34f_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_3e34f_row2_col0" class="data row2 col0" >747.8227</td>
#       <td id="T_3e34f_row2_col1" class="data row2 col1" >2302441.7449</td>
#       <td id="T_3e34f_row2_col2" class="data row2 col2" >1517.3799</td>
#       <td id="T_3e34f_row2_col3" class="data row2 col3" >0.9789</td>
#       <td id="T_3e34f_row2_col4" class="data row2 col4" >0.0795</td>
#       <td id="T_3e34f_row2_col5" class="data row2 col5" >0.0581</td>
#     </tr>
#     <tr>
#       <th id="T_3e34f_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_3e34f_row3_col0" class="data row3 col0" >700.3420</td>
#       <td id="T_3e34f_row3_col1" class="data row3 col1" >1485922.9146</td>
#       <td id="T_3e34f_row3_col2" class="data row3 col2" >1218.9844</td>
#       <td id="T_3e34f_row3_col3" class="data row3 col3" >0.9836</td>
#       <td id="T_3e34f_row3_col4" class="data row3 col4" >0.0733</td>
#       <td id="T_3e34f_row3_col5" class="data row3 col5" >0.0558</td>
#     </tr>
#     <tr>
#       <th id="T_3e34f_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_3e34f_row4_col0" class="data row4 col0" >640.5664</td>
#       <td id="T_3e34f_row4_col1" class="data row4 col1" >1238780.4181</td>
#       <td id="T_3e34f_row4_col2" class="data row4 col2" >1113.0051</td>
#       <td id="T_3e34f_row4_col3" class="data row4 col3" >0.9845</td>
#       <td id="T_3e34f_row4_col4" class="data row4 col4" >0.0784</td>
#       <td id="T_3e34f_row4_col5" class="data row4 col5" >0.0562</td>
#     </tr>
#     <tr>
#       <th id="T_3e34f_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_3e34f_row5_col0" class="data row5 col0" >835.2700</td>
#       <td id="T_3e34f_row5_col1" class="data row5 col1" >7118965.6263</td>
#       <td id="T_3e34f_row5_col2" class="data row5 col2" >2668.1390</td>
#       <td id="T_3e34f_row5_col3" class="data row5 col3" >0.9392</td>
#       <td id="T_3e34f_row5_col4" class="data row5 col4" >0.0810</td>
#       <td id="T_3e34f_row5_col5" class="data row5 col5" >0.0557</td>
#     </tr>
#     <tr>
#       <th id="T_3e34f_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_3e34f_row6_col0" class="data row6 col0" >863.4444</td>
#       <td id="T_3e34f_row6_col1" class="data row6 col1" >3512642.3609</td>
#       <td id="T_3e34f_row6_col2" class="data row6 col2" >1874.2045</td>
#       <td id="T_3e34f_row6_col3" class="data row6 col3" >0.9670</td>
#       <td id="T_3e34f_row6_col4" class="data row6 col4" >0.0848</td>
#       <td id="T_3e34f_row6_col5" class="data row6 col5" >0.0621</td>
#     </tr>
#     <tr>
#       <th id="T_3e34f_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_3e34f_row7_col0" class="data row7 col0" >714.5869</td>
#       <td id="T_3e34f_row7_col1" class="data row7 col1" >2576734.1429</td>
#       <td id="T_3e34f_row7_col2" class="data row7 col2" >1605.2209</td>
#       <td id="T_3e34f_row7_col3" class="data row7 col3" >0.9674</td>
#       <td id="T_3e34f_row7_col4" class="data row7 col4" >0.0752</td>
#       <td id="T_3e34f_row7_col5" class="data row7 col5" >0.0537</td>
#     </tr>
#     <tr>
#       <th id="T_3e34f_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_3e34f_row8_col0" class="data row8 col0" >740.6562</td>
#       <td id="T_3e34f_row8_col1" class="data row8 col1" >2290888.7570</td>
#       <td id="T_3e34f_row8_col2" class="data row8 col2" >1513.5682</td>
#       <td id="T_3e34f_row8_col3" class="data row8 col3" >0.9775</td>
#       <td id="T_3e34f_row8_col4" class="data row8 col4" >0.0781</td>
#       <td id="T_3e34f_row8_col5" class="data row8 col5" >0.0564</td>
#     </tr>
#     <tr>
#       <th id="T_3e34f_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_3e34f_row9_col0" class="data row9 col0" >764.6396</td>
#       <td id="T_3e34f_row9_col1" class="data row9 col1" >2545439.6689</td>
#       <td id="T_3e34f_row9_col2" class="data row9 col2" >1595.4434</td>
#       <td id="T_3e34f_row9_col3" class="data row9 col3" >0.9758</td>
#       <td id="T_3e34f_row9_col4" class="data row9 col4" >0.0891</td>
#       <td id="T_3e34f_row9_col5" class="data row9 col5" >0.0610</td>
#     </tr>
#     <tr>
#       <th id="T_3e34f_level0_row10" class="row_heading level0 row10" >Mean</th>
#       <td id="T_3e34f_row10_col0" class="data row10 col0" >766.0853</td>
#       <td id="T_3e34f_row10_col1" class="data row10 col1" >3116466.5642</td>
#       <td id="T_3e34f_row10_col2" class="data row10 col2" >1704.0975</td>
#       <td id="T_3e34f_row10_col3" class="data row10 col3" >0.9704</td>
#       <td id="T_3e34f_row10_col4" class="data row10 col4" >0.0799</td>
#       <td id="T_3e34f_row10_col5" class="data row10 col5" >0.0576</td>
#     </tr>
#     <tr>
#       <th id="T_3e34f_level0_row11" class="row_heading level0 row11" >Std</th>
#       <td id="T_3e34f_row11_col0" class="data row11 col0" >73.2848</td>
#       <td id="T_3e34f_row11_col1" class="data row11 col1" >1774309.7552</td>
#       <td id="T_3e34f_row11_col2" class="data row11 col2" >460.9970</td>
#       <td id="T_3e34f_row11_col3" class="data row11 col3" >0.0131</td>
#       <td id="T_3e34f_row11_col4" class="data row11 col4" >0.0043</td>
#       <td id="T_3e34f_row11_col5" class="data row11 col5" >0.0024</td>
#     </tr>
#   </tbody>
# </table>

# %%
import numpy as np
lgbm_params = {'num_leaves': np.arange(10,200,10),
                        'max_depth': [int(x) for x in np.linspace(10, 110, num = 11)],
                        'learning_rate': np.arange(0.1,1,0.1)
                        }

tuned_lightgbm = tune_model(lightgbm, 
                            custom_grid = lgbm_params)
# Out:
# <style type="text/css">
# #T_e48fb_row10_col0, #T_e48fb_row10_col1, #T_e48fb_row10_col2, #T_e48fb_row10_col3, #T_e48fb_row10_col4, #T_e48fb_row10_col5 {
#   background: yellow;
# }
# </style>
# <table id="T_e48fb">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_e48fb_level0_col0" class="col_heading level0 col0" >MAE</th>
#       <th id="T_e48fb_level0_col1" class="col_heading level0 col1" >MSE</th>
#       <th id="T_e48fb_level0_col2" class="col_heading level0 col2" >RMSE</th>
#       <th id="T_e48fb_level0_col3" class="col_heading level0 col3" >R2</th>
#       <th id="T_e48fb_level0_col4" class="col_heading level0 col4" >RMSLE</th>
#       <th id="T_e48fb_level0_col5" class="col_heading level0 col5" >MAPE</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Fold</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_e48fb_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_e48fb_row0_col0" class="data row0 col0" >822.6400</td>
#       <td id="T_e48fb_row0_col1" class="data row0 col1" >2569287.7739</td>
#       <td id="T_e48fb_row0_col2" class="data row0 col2" >1602.8998</td>
#       <td id="T_e48fb_row0_col3" class="data row0 col3" >0.9718</td>
#       <td id="T_e48fb_row0_col4" class="data row0 col4" >0.0868</td>
#       <td id="T_e48fb_row0_col5" class="data row0 col5" >0.0641</td>
#     </tr>
#     <tr>
#       <th id="T_e48fb_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_e48fb_row1_col0" class="data row1 col0" >1008.9226</td>
#       <td id="T_e48fb_row1_col1" class="data row1 col1" >6724757.6372</td>
#       <td id="T_e48fb_row1_col2" class="data row1 col2" >2593.2138</td>
#       <td id="T_e48fb_row1_col3" class="data row1 col3" >0.9485</td>
#       <td id="T_e48fb_row1_col4" class="data row1 col4" >0.0860</td>
#       <td id="T_e48fb_row1_col5" class="data row1 col5" >0.0618</td>
#     </tr>
#     <tr>
#       <th id="T_e48fb_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_e48fb_row2_col0" class="data row2 col0" >815.8761</td>
#       <td id="T_e48fb_row2_col1" class="data row2 col1" >2461914.7737</td>
#       <td id="T_e48fb_row2_col2" class="data row2 col2" >1569.0490</td>
#       <td id="T_e48fb_row2_col3" class="data row2 col3" >0.9774</td>
#       <td id="T_e48fb_row2_col4" class="data row2 col4" >0.0857</td>
#       <td id="T_e48fb_row2_col5" class="data row2 col5" >0.0628</td>
#     </tr>
#     <tr>
#       <th id="T_e48fb_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_e48fb_row3_col0" class="data row3 col0" >805.5570</td>
#       <td id="T_e48fb_row3_col1" class="data row3 col1" >2066452.6946</td>
#       <td id="T_e48fb_row3_col2" class="data row3 col2" >1437.5162</td>
#       <td id="T_e48fb_row3_col3" class="data row3 col3" >0.9772</td>
#       <td id="T_e48fb_row3_col4" class="data row3 col4" >0.0805</td>
#       <td id="T_e48fb_row3_col5" class="data row3 col5" >0.0620</td>
#     </tr>
#     <tr>
#       <th id="T_e48fb_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_e48fb_row4_col0" class="data row4 col0" >814.8100</td>
#       <td id="T_e48fb_row4_col1" class="data row4 col1" >2151031.1608</td>
#       <td id="T_e48fb_row4_col2" class="data row4 col2" >1466.6394</td>
#       <td id="T_e48fb_row4_col3" class="data row4 col3" >0.9732</td>
#       <td id="T_e48fb_row4_col4" class="data row4 col4" >0.0904</td>
#       <td id="T_e48fb_row4_col5" class="data row4 col5" >0.0664</td>
#     </tr>
#     <tr>
#       <th id="T_e48fb_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_e48fb_row5_col0" class="data row5 col0" >881.7793</td>
#       <td id="T_e48fb_row5_col1" class="data row5 col1" >4766151.7412</td>
#       <td id="T_e48fb_row5_col2" class="data row5 col2" >2183.1518</td>
#       <td id="T_e48fb_row5_col3" class="data row5 col3" >0.9593</td>
#       <td id="T_e48fb_row5_col4" class="data row5 col4" >0.0838</td>
#       <td id="T_e48fb_row5_col5" class="data row5 col5" >0.0608</td>
#     </tr>
#     <tr>
#       <th id="T_e48fb_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_e48fb_row6_col0" class="data row6 col0" >951.9875</td>
#       <td id="T_e48fb_row6_col1" class="data row6 col1" >4092100.1761</td>
#       <td id="T_e48fb_row6_col2" class="data row6 col2" >2022.8940</td>
#       <td id="T_e48fb_row6_col3" class="data row6 col3" >0.9616</td>
#       <td id="T_e48fb_row6_col4" class="data row6 col4" >0.0906</td>
#       <td id="T_e48fb_row6_col5" class="data row6 col5" >0.0662</td>
#     </tr>
#     <tr>
#       <th id="T_e48fb_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_e48fb_row7_col0" class="data row7 col0" >872.9769</td>
#       <td id="T_e48fb_row7_col1" class="data row7 col1" >3230168.8544</td>
#       <td id="T_e48fb_row7_col2" class="data row7 col2" >1797.2671</td>
#       <td id="T_e48fb_row7_col3" class="data row7 col3" >0.9592</td>
#       <td id="T_e48fb_row7_col4" class="data row7 col4" >0.0889</td>
#       <td id="T_e48fb_row7_col5" class="data row7 col5" >0.0654</td>
#     </tr>
#     <tr>
#       <th id="T_e48fb_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_e48fb_row8_col0" class="data row8 col0" >790.5395</td>
#       <td id="T_e48fb_row8_col1" class="data row8 col1" >2393344.9164</td>
#       <td id="T_e48fb_row8_col2" class="data row8 col2" >1547.0439</td>
#       <td id="T_e48fb_row8_col3" class="data row8 col3" >0.9765</td>
#       <td id="T_e48fb_row8_col4" class="data row8 col4" >0.0801</td>
#       <td id="T_e48fb_row8_col5" class="data row8 col5" >0.0609</td>
#     </tr>
#     <tr>
#       <th id="T_e48fb_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_e48fb_row9_col0" class="data row9 col0" >894.5596</td>
#       <td id="T_e48fb_row9_col1" class="data row9 col1" >3397524.2123</td>
#       <td id="T_e48fb_row9_col2" class="data row9 col2" >1843.2374</td>
#       <td id="T_e48fb_row9_col3" class="data row9 col3" >0.9676</td>
#       <td id="T_e48fb_row9_col4" class="data row9 col4" >0.0938</td>
#       <td id="T_e48fb_row9_col5" class="data row9 col5" >0.0675</td>
#     </tr>
#     <tr>
#       <th id="T_e48fb_level0_row10" class="row_heading level0 row10" >Mean</th>
#       <td id="T_e48fb_row10_col0" class="data row10 col0" >865.9649</td>
#       <td id="T_e48fb_row10_col1" class="data row10 col1" >3385273.3940</td>
#       <td id="T_e48fb_row10_col2" class="data row10 col2" >1806.2912</td>
#       <td id="T_e48fb_row10_col3" class="data row10 col3" >0.9672</td>
#       <td id="T_e48fb_row10_col4" class="data row10 col4" >0.0867</td>
#       <td id="T_e48fb_row10_col5" class="data row10 col5" >0.0638</td>
#     </tr>
#     <tr>
#       <th id="T_e48fb_level0_row11" class="row_heading level0 row11" >Std</th>
#       <td id="T_e48fb_row11_col0" class="data row11 col0" >67.3012</td>
#       <td id="T_e48fb_row11_col1" class="data row11 col1" >1390962.9516</td>
#       <td id="T_e48fb_row11_col2" class="data row11 col2" >350.1219</td>
#       <td id="T_e48fb_row11_col3" class="data row11 col3" >0.0093</td>
#       <td id="T_e48fb_row11_col4" class="data row11 col4" >0.0042</td>
#       <td id="T_e48fb_row11_col5" class="data row11 col5" >0.0023</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ### Evaluate the model

# %%
# check the residuals of trained model
plot_model(tuned_best, plot = 'residuals')

# %%
# check feature importance
plot_model(tuned_best, plot = 'feature')

# %%
plot_model(tuned_best, plot = 'error')

# %%
evaluate_model(tuned_best)
# Out:
# interactive(children=(ToggleButtons(description='Plot Type:', icons=('',), options=(('Hyperparameters', 'param…

# %% [markdown]
# ### Interpretability

# %%
# Global Plot Settings
fig_kwargs={'renderer': 'notebook'}
import matplotlib.pyplot as plt
plt.figure(figsize = (18,9))

interpret = interpret_model(tuned_best)

# %%
interpret_model(tuned_best, plot = 'reason', observation = 12)
# Out:
# <div align='center'><img src='data:image/png;base64,...' /></div><script charset='utf-8'>!function(t){function e(r){if(n[r])return n[r].exports;var i=n[r]={i:r,l:!1,exports:{}};return t[r].call(i.exports,i,i.exports,e),i.l=!0,i.exports}var n={};return e.m=t,e.c=n,e.i=function(t){return t},e.d=function(t,n,r){e.o(t,n)||Object.defineProperty(t,n,{configurable:!1,enumerable:!0,get:r})},e.n=function(t){var n=t&&t.__esModule?function(){return t.default}:function(){return t};return e.d(n,"a",n),n},e.o=function(t,e){return Object.prototype.hasOwnProperty.call(t,e)},e.p="",e(e.s=410)}([function(t,e,n){"use strict";function r(t,e,n,r,o,a,u,c){if(i(e),!t){var s;if(void 0===e)s=new Error("Minified exception occurred; use the non-minified dev environment for the full error message and additional helpful warnings.");else{var l=[n,r,o,a,u,c],f=0;s=new Error(e.replace(/%s/g,function(){return l[f++]})),s.name="Invariant Violation"}throw s.framesToPop=1,s}}var i=function(t){};t.exports=r},function(t,e,n){"use strict";var r=n(8),i=r;t.exports=i},function(t,e,n){"use strict";function r(t){for(var e=arguments.length-1,n="Minified React error #"+t+"; visit http://facebook.github.io/react/docs/error-decoder.html?invariant="+t,r=0;r<e;r++)n+="&args[]="+encodeURIComponent(arguments[r+1]);n+=" for the full message or use the non-minified dev environment for full errors and additional helpful warnings.";var i=new Error(n);throw i.name="Invariant Violation",i.framesToPop=1,i}t.exports=r},function(t,e,n){"use strict";function r(t){if(null===t||void 0===t)throw new TypeError("Object.assign cannot be called with null or undefined");return Object(t)}function i(){try{if(!Object.assign)return!1;var t=new String("abc");if(t[5]="de","5"===Object.getOwnPropertyNames(t)[0])return!1;for(var e={},n=0;n<10;n++)e["_"+String.fromCharCode(n)]=n;var r=Object.getOwnPropertyNames(e).map(function(t){return e[t]});if("0123456789"!==r.join(""))return!1;var i={};return"abcdefghijklmnopqrst".split("").forEach(function(t){i[t]=t}),"abcdefghijklmnopqrst"===Object.keys(Object.assign({},i)).join("")}catch(t){return!1}}/*
# object-assign
# (c) Sindre Sorhus
# @license MIT
# */
# var o=Object.getOwnPropertySymbols,a=Object.prototype.hasOwnProperty,u=Object.prototype.propertyIsEnumerable;t.exports=i()?Object.assign:function(t,e){for(var n,i,c=r(t),s=1;s<arguments.length;s++){n=Object(arguments[s]);for(var l in n)a.call(n,l)&&(c[l]=n[l]);if(o){i=o(n);for(var f=0;f<i.length;f++)u.call(n,i[f])&&(c[i[f]]=n[i[f]])}}return c}},function(t,e,n){"use strict";function r(t,e){return 1===t.nodeType&&t.getAttribute(d)===String(e)||8===t.nodeType&&t.nodeValue===" react-text: "+e+" "||8===t.nodeType&&t.nodeValue===" react-empty: "+e+" "}function i(t){for(var e;e=t._renderedComponent;)t=e;return t}function o(t,e){var n=i(t);n._hostNode=e,e[g]=n}function a(t){var e=t._hostNode;e&&(delete e[g],t._hostNode=null)}function u(t,e){if(!(t._flags&v.hasCachedChildNodes)){var n=t._renderedChildren,a=e.firstChild;t:for(var u in n)if(n.hasOwnProperty(u)){var c=n[u],s=i(c)._domID;if(0!==s){for(;null!==a;a=a.nextSibling)if(r(a,s)){o(c,a);continue t}f("32",s)}}t._flags|=v.hasCachedChildNodes}}function c(t){if(t[g])return t[g];for(var e=[];!t[g];){if(e.push(t),!t.parentNode)return null;t=t.parentNode}for(var n,r;t&&(r=t[g]);t=e.pop())n=r,e.length&&u(r,t);return n}function s(t){var e=c(t);return null!=e&&e._hostNode===t?e:null}function l(t){if(void 0===t._hostNode?f("33"):void 0,t._hostNode)return t._hostNode;for(var e=[];!t._hostNode;)e.push(t),t._hostParent?void 0:f("34"),t=t._hostParent;for(;e.length;t=e.pop())u(t,t._hostNode);return t._hostNode}var f=n(2),p=n(21),h=n(157),d=(n(0),p.ID_ATTRIBUTE_NAME),v=h,g="__reactInternalInstance$"+Math.random().toString(36).slice(2),m={getClosestInstanceFromNode:c,getInstanceFromNode:s,getNodeFromInstance:l,precacheChildNodes:u,precacheNode:o,uncacheNode:a};t.exports=m},function(t,e,n){"use strict";function r(t,e,n,a){function u(e){return t(e=new Date(+e)),e}return u.floor=u,u.ceil=function(n){return t(n=new Date(n-1)),e(n,1),t(n),n},u.round=function(t){var e=u(t),n=u.ceil(t);return t-e<n-t?e:n},u.offset=function(t,n){return e(t=new Date(+t),null==n?1:Math.floor(n)),t},u.range=function(n,r,i){var o=[];if(n=u.ceil(n),i=null==i?1:Math.floor(i),!(n<r&&i>0))return o;do o.push(new Date(+n));while(e(n,i),t(n),n<r);return o},u.filter=function(n){return r(function(e){if(e>=e)for(;t(e),!n(e);)e.setTime(e-1)},function(t,r){if(t>=t)for(;--r>=0;)for(;e(t,1),!n(t););})},n&&(u.count=function(e,r){return i.setTime(+e),o.setTime(+r),t(i),t(o),Math.floor(n(i,o))},u.every=function(t){return t=Math.floor(t),isFinite(t)&&t>0?t>1?u.filter(a?function(e){return a(e)%t===0}:function(e){return u.count(0,e)%t===0}):u:null}),u}e.a=r;var i=new Date,o=new Date},function(t,e,n){"use strict";var r=!("undefined"==typeof window||!window.document||!window.document.createElement),i={canUseDOM:r,canUseWorkers:"undefined"!=typeof Worker,canUseEventListeners:r&&!(!window.addEventListener&&!window.attachEvent),canUseViewport:r&&!!window.screen,isInWorker:!r};t.exports=i},function(t,e,n){"use strict";function r(t,e){this._groups=t,this._parents=e}function i(){return new r([[document.documentElement]],D)}var o=n(272),a=n(273),u=n(261),c=n(255),s=n(131),l=n(260),f=n(265),p=n(268),h=n(275),d=n(253),v=n(267),g=n(266),m=n(274),y=n(259),_=n(258),b=n(252),x=n(276),w=n(269),C=n(254),M=n(277),k=n(262),E=n(270),T=n(264),S=n(251),P=n(263),N=n(271),A=n(256),O=n(70),I=n(257);n.d(e,"c",function(){return D}),e.b=r;var D=[null];r.prototype=i.prototype={constructor:r,select:o.a,selectAll:a.a,filter:u.a,data:c.a,enter:s.a,exit:l.a,merge:f.a,order:p.a,sort:h.a,call:d.a,nodes:v.a,node:g.a,size:m.a,empty:y.a,each:_.a,attr:b.a,style:x.a,property:w.a,classed:C.a,text:M.a,html:k.a,raise:E.a,lower:T.a,append:S.a,insert:P.a,remove:N.a,datum:A.a,on:O.c,dispatch:I.a},e.a=i},function(t,e,n){"use strict";function r(t){return function(){return t}}var i=function(){};i.thatReturns=r,i.thatReturnsFalse=r(!1),i.thatReturnsTrue=r(!0),i.thatReturnsNull=r(null),i.thatReturnsThis=function(){return this},i.thatReturnsArgument=function(t){return t},t.exports=i},function(t,e,n ...
# <div id='iO2Z3RU8SVRWWW8UFLPJY'>
# <div style='color: #900; text-align: center;'>
#   <b>Visualization omitted, Javascript library not loaded!</b><br>
#   Have you run `initjs()` in this notebook? If this notebook was from another
#   user you must also trust this notebook (File -> Trust notebook). If you are viewing
#   this notebook on github the Javascript has been stripped for security. If you are using
#   JupyterLab this error is because a JupyterLab extension has not yet been written.
# </div></div>
#  <script>
#    if (window.SHAP) SHAP.ReactDom.render(
#     SHAP.React.createElement(SHAP.AdditiveForceVisualizer, {"outNames": ["f(x)"], "baseValue": -5.091373150963949e-05, "outValue": 1.211550296628015, "link": "identity", "featureNames": ["Cut_Fair", "Cut_Good", "Cut_Ideal", "Cut_Signature-Ideal", "Cut_Very Good", "Color_D", "Color_E", "Color_F", "Color_G", "Color_H", "Color_I", "Clarity_FL", "Clarity_IF", "Clarity_SI1", "Clarity_VS1", "Clarity_VS2", "Clarity_VVS1", "Clarity_VVS2", "Polish_EX", "Polish_G", "Polish_VG", "Symmetry_EX", "Symmetry_G", "Symmetry_ID", "Symmetry_VG", "Report_GIA", "Carat Weight_0.0", "Carat Weight_1.0", "Carat Weight_10.0", "Carat Weight_11.0", "Carat Weight_12.0", "Carat Weight_2.0", "Carat Weight_3.0", "Carat Weight_4.0", "Carat Weight_5.0", "Carat Weight_6.0", "Carat Weight_7.0", "Carat Weight_8.0", "Carat Weight_9.0"], "features": {"0": {"effect": 0.0031398833968351992, "value": 0.0}, "1": {"effect": 0.002876409622405879, "value": 0.0}, "2": {"effect": -0.02022535058351293, "value": 0.0}, "3": {"effect": -0.01254272787379117, "value": 0.0}, "4": {"effect": 0.006551619987231293, "value": 1.0}, "5": {"effect": -0.0176535394046797, "value": 0.0}, "6": {"effect": -0.009499049856710066, "value": 0.0}, "7": {"effect": 0.04055378297360056, "value": 1.0}, "8": {"effect": 0.011203868812766282, "value": 0.0}, "9": {"effect": 0.03274850124411029, "value": 0.0}, "10": {"effect": 0.060698450234766575, "value": 0.0}, "11": {"effect": -0.00020819293469074928, "value": 0.0}, "12": {"effect": -0.013854575200934265, "value": 0.0}, "13": {"effect": -0.2600117806172759, "value": 1.0}, "14": {"effect": 0.0008349381436278274, "value": 0.0}, "15": {"effect": 0.019411882530611786, "value": 0.0}, "16": {"effect": -0.011758814817433433, "value": 0.0}, "17": {"effect": -0.016318390222312216, "value": 0.0}, "18": {"effect": 0.012604969248939352, "value": 1.0}, "19": {"effect": 0.0005320216428923437, "value": 0.0}, "20": {"effect": -0.0009642813303351574, "value": 0.0}, "21": {"effect": -0.0015622945195584031, "value": 0.0}, "22": {"effect": 0.0015146165447708759, "value": 0.0}, "23": {"effect": -0.0017527685420796555, "value": 0.0}, "24": {"effect": -0.007020777800368303, "value": 1.0}, "25": {"effect": 0.0014174884869472947, "value": 1.0}, "26": {"effect": 0.12559118912711034, "value": 0.0}, "27": {"effect": 0.04716233331066542, "value": 0.0}, "28": {"effect": 0.9868016090625978, "value": 1.0}, "29": {"effect": -0.007885623788707316, "value": 0.0}, "30": {"effect": -0.009790960610537353, "value": 0.0}, "31": {"effect": 0.1498610440038092, "value": 0.0}, "32": {"effect": 0.058815929985147744, "value": 0.0}, "33": {"effect": 0.022461972026491347, "value": 0.0}, "34": {"effect": 0.012644611657434805, "value": 0.0}, "35": {"effect": -0.0033833405908063924, "value": 0.0}, "36": {"effect": -0.005969901946539806, "value": 0.0}, "37": {"effect": 0.020277663629729218, "value": 0.0}, "38": {"effect": -0.0057012046726941865, "value": 0.0}}, "plot_cmap": "RdBu", "labelMargin": 20}),
#     document.getElementById('iO2Z3RU8SVRWWW8UFLPJY')
#   );
# </script>

# %% [markdown]
# ### Explainer Dashboard

# %%
dashboard(tuned_best, display_format = 'inline')
# Out:
# WARNING: Parameter shap='guess', but failed to guess the type of shap explainer to use for PowerTransformedTargetRegressor. Defaulting to the model agnostic shap.KernelExplainer (shap='kernel'). However this will be slow, so if your model is compatible with e.g. shap.TreeExplainer or shap.LinearExplainer then pass shap='tree' or shap='linear'!
# WARNING: For shap='kernel', shap interaction values can unfortunately not be calculated!
# Warning: shap values for shap.KernelExplainer get calculated against X_background, but paramater X_background=None, so using shap.sample(X, 50) instead
# Generating self.shap_explainer = shap.KernelExplainer(model, X)...
# Provided model function fails when applied to the provided data set.
# ---------------------------------------------------------------------------
# CatBoostError                             Traceback (most recent call last)
# Input In [17], in <cell line: 1>()
# ----> 1 dashboard(tuned_best, display_format = 'inline')
#
# File ~\anaconda3\envs\ml_pycaret\lib\site-packages\pycaret\regression.py:2670, in dashboard(estimator, display_format, dashboard_kwargs, run_kwargs, **kwargs)
#    2622 def dashboard(
#    2623     estimator, display_format="dash", dashboard_kwargs={}, run_kwargs={}, **kwargs
#    2624 ):
#    2625     """
#    2626     This function generates the interactive dashboard for a trained model. The
#    2627     dashboard is implemented using ExplainerDashboard (explainerdashboard.readthedocs.io)
#    (...)
#    2668         None
#    2669     """
# -> 2670     return pycaret.internal.tabular.dashboard(
#    2671         estimator, display_format, dashboard_kwargs, run_kwargs, **kwargs
#    2672     )
#
# File ~\anaconda3\envs\ml_pycaret\lib\site-packages\pycaret\internal\tabular.py:10600, in dashboard(estimator, display_format, dashboard_kwargs, run_kwargs, **kwargs)
#   10591     _create_classification_dashboard(
#   10592         model=estimator,
#   10593         mode=display_format,
#    (...)
#   10596         **kwargs,
#   10597     )
#   10599 elif _ml_usecase == MLUsecase.REGRESSION:
# > 10600     _create_regression_dashboard(
#   10601         model=estimator,
#   10602         mode=display_format,
#   10603         dashboard_kwargs=dashboard_kwargs,
#   10604         run_kwargs=run_kwargs,
#   10605         **kwargs,
#   10606     )
#
# File ~\anaconda3\envs\ml_pycaret\lib\site-packages\pycaret\internal\tabular.py:10624, in _create_regression_dashboard(model, mode, dashboard_kwargs, run_kwargs, **kwargs)
#   10619 X_test_df = get_config("X_test")
#   10620 X_test_df.columns = [
#   10621     col.replace(".", "__").replace("{", "__").replace("}", "__")
#   10622     for col in X_test_df.columns
#   10623 ]
# > 10624 explainer = RegressionExplainer(model, X_test_df, get_config("y_test"), **kwargs)
#   10625 ExplainerDashboard(explainer, mode=mode, **dashboard_kwargs).run(**run_kwargs)
#
# File ~\anaconda3\envs\ml_pycaret\lib\site-packages\explainerdashboard\explainers.py:3240, in RegressionExplainer.__init__(self, model, X, y, permutation_metric, shap, X_background, model_output, cats, cats_notencoded, idxs, index_name, target, descriptions, n_jobs, permutation_cv, cv, na_fill, precision, units)
#    3237     print(f"Changing class type to XGBRegressionExplainer...", flush=True)
#    3238     self.__class__ = XGBRegressionExplainer
# -> 3240 _ = self.shap_explainer
#
# File ~\anaconda3\envs\ml_pycaret\lib\site-packages\explainerdashboard\explainers.py:908, in BaseExplainer.shap_explainer(self)
#     905             data_asframe =  pd.DataFrame(data_asarray, columns=self.columns)
#     906             return self.model.predict(data_asframe)
# --> 908         self._shap_explainer = shap.KernelExplainer(model_predict,
#     909             self.X_background if self.X_background is not None \
#     910                 else shap.sample(self.X, 50))
#     911 return self._shap_explainer
#
# File ~\anaconda3\envs\ml_pycaret\lib\site-packages\shap\explainers\_kernel.py:69, in Kernel.__init__(self, model, data, link, **kwargs)
#      67 self.keep_index_ordered = kwargs.get("keep_index_ordered", False)
#      68 self.data = convert_to_data(data, keep_index=self.keep_index)
# ---> 69 model_null = match_model_to_data(self.model, self.data)
#      71 # enforce our current input type limitations
#      72 assert isinstance(self.data, DenseData) or isinstance(self.data, SparseData), \
#      73        "Shap explainer only supports the DenseData and SparseData input currently."
#
# File ~\anaconda3\envs\ml_pycaret\lib\site-packages\shap\utils\_legacy.py:112, in match_model_to_data(model, data)
#     110         out_val = model.f(data.convert_to_df())
#     111     else:
# --> 112         out_val = model.f(data.data)
#     113 except:
#     114     print("Provided model function fails when applied to the provided data set.")
#
# File ~\anaconda3\envs\ml_pycaret\lib\site-packages\explainerdashboard\explainers.py:906, in BaseExplainer.shap_explainer.<locals>.model_predict(data_asarray)
#     904 def model_predict(data_asarray):
#     905     data_asframe =  pd.DataFrame(data_asarray, columns=self.columns)
# --> 906     return self.model.predict(data_asframe)
#
# File ~\anaconda3\envs\ml_pycaret\lib\site-packages\sklearn\compose\_target.py:229, in TransformedTargetRegressor.predict(self, X)
#     212 """Predict using the base regressor, applying inverse.
#     213
#     214 The regressor is used to predict and the ``inverse_func`` or
#    (...)
#     226
#     227 """
#     228 check_is_fitted(self)
# --> 229 pred = self.regressor_.predict(X)
#     230 if pred.ndim == 1:
#     231     pred_trans = self.transformer_.inverse_transform(
#     232         pred.reshape(-1, 1))
#
# File ~\anaconda3\envs\ml_pycaret\lib\site-packages\catboost\core.py:5549, in CatBoostRegressor.predict(self, data, prediction_type, ntree_start, ntree_end, thread_count, verbose, task_type)
#    5547 if prediction_type is None:
#    5548     prediction_type = self._get_default_prediction_type()
# -> 5549 return self._predict(data, prediction_type, ntree_start, ntree_end, thread_count, verbose, 'predict', task_type)
#
# File ~\anaconda3\envs\ml_pycaret\lib\site-packages\catboost\core.py:2375, in CatBoost._predict(self, data, prediction_type, ntree_start, ntree_end, thread_count, verbose, parent_method_name, task_type)
#    2372 data, data_is_single_object = self._process_predict_input_data(data, parent_method_name, thread_count)
#    2373 self._validate_prediction_type(prediction_type)
# -> 2375 predictions = self._base_predict(data, prediction_type, ntree_start, ntree_end, thread_count, verbose, task_type)
#    2376 return predictions[0] if data_is_single_object else predictions
#
# File ~\anaconda3\envs\ml_pycaret\lib\site-packages\catboost\core.py:1671, in _CatBoostBase._base_predict(self, pool, prediction_type, ntree_start, ntree_end, thread_count, verbose, task_type)
#    1670 def _base_predict(self, pool, prediction_type, ntree_start, ntree_end, thread_count, verbose, task_type):
# -> 1671     return self._object._base_predict(pool, prediction_type, ntree_start, ntree_end, thread_count, verbose, task_type)
#
# File _catboost.pyx:4544, in _catboost._CatBoost._base_predict()
#
# File _catboost.pyx:4551, in _catboost._CatBoost._base_predict()
#
# CatBoostError: C:/Program Files (x86)/Go Agent/pipelines/BuildMaster/catboost.git/catboost/libs/data/model_dataset_compatibility.cpp:81: At position 26 should be feature with name Carat Weight_0.0 (found Carat Weight_0__0).
